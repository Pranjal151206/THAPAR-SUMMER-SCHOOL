# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjal151206/THAPAR-SUMMER-SCHOOL/blob/main/Mini_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2025-06-23 085344.png](data:image/png;base64,...)

# %%
L= ["Ram", 1, "Shyam", 2, "Aman",3]
L1= []
L2 = []
for i in L:
    if (type(i)==int):
        L1.append(i)
    else :
        L2.append(i)
L.clear
L1.sort()
L2.sort()
L=[L1 + L2]
print(L)
# Out:
# [[1, 2, 3, 'Aman', 'Ram', 'Shyam']]
