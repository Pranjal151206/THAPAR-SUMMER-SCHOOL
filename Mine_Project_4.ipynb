# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjal151206/THAPAR-SUMMER-SCHOOL/blob/main/Mine_Project_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
productlist = {'p1':10, 'p2':15, 'p3':20, 'p4':25, 'p5':30, 'p6':35, 'p7':50,
               'p8':40, 'p9':55, 'p10':60, 'p11':65, 'p12':75, 'p13':70,
               'p14':45}

# %%
from itertools import combinations

# %%
l = []
keys = list(productlist.keys())

for i in range (1, len(keys) + 1):
  for j in combinations(keys, i):
    total = sum(productlist[k] for k in j)
    if (280 <= total <= 320):
      l.append(j)

print("total subsets = ", len(l))
for i in l:
  print(i)
# Out:
# total subsets =  3212
# ('p1', 'p10', 'p11', 'p12', 'p13')
# ('p2', 'p9', 'p11', 'p12', 'p13')
# ('p2', 'p10', 'p11', 'p12', 'p13')
# ('p3', 'p7', 'p11', 'p12', 'p13')
# ('p3', 'p9', 'p10', 'p12', 'p13')
# ('p3', 'p9', 'p11', 'p12', 'p13')
# ('p3', 'p10', 'p11', 'p12', 'p13')
# ('p4', 'p7', 'p10', 'p12', 'p13')
# ('p4', 'p7', 'p11', 'p12', 'p13')
# ('p4', 'p9', 'p10', 'p11', 'p12')
# ('p4', 'p9', 'p10', 'p12', 'p13')
# ('p4', 'p9', 'p11', 'p12', 'p13')
# ('p4', 'p10', 'p11', 'p12', 'p13')
# ('p4', 'p11', 'p12', 'p13', 'p14')
# ('p5', 'p7', 'p9', 'p12', 'p13')
# ('p5', 'p7', 'p10', 'p11', 'p12')
# ('p5', 'p7', 'p10', 'p12', 'p13')
# ('p5', 'p7', 'p11', 'p12', 'p13')
# ('p5', 'p8', 'p11', 'p12', 'p13')
# ('p5', 'p9', 'p10', 'p11', 'p12')
# ('p5', 'p9', 'p10', 'p11', 'p13')
# ('p5', 'p9', 'p10', 'p12', 'p13')
# ('p5', 'p9', 'p11', 'p12', 'p13')
# ('p5', 'p10', 'p11', 'p12', 'p13')
# ('p5', 'p10', 'p12', 'p13', 'p14')
# ('p5', 'p11', 'p12', 'p13', 'p14')
# ...
